# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("homeprices multiple.csv")
data
# Out:
#     AREA  BEDROOMS   PRICE
# 0   2600         3  550000
# 1   3000         4  565000
# 2   3200         1  610000
# 3   3600         3  595000
# 4   4000         5  760000
# 5   4100         6  810000
# 6   3400         2  590000
# 7   3800         4  675000
# 8   3300         3  600000
# 9   3700         2  620000
# 10  4200         5  750000
# 11  4300         4  800000
# 12  2800         2  580000
# 13  3100         3  590000
# 14  3300         2  620000
# 15  3600         4  640000
# 16  3900         3  720000
# 17  3200         2  610000
# 18  3100         3  650000
# 19  3300         2  580000
# 20  3700         3  680000
# 21  4100         5  790000
# 22  3800         4  710000
# 23  4300         3  780000
# 24  3000         3  600000
# 25  3200         4  640000
# 26  3400         2  590000
# 27  3500         3  650000
# 28  4000         4  730000
# 29  4100         5  780000

# %%
X = data[['AREA', 'BEDROOMS']].values
y = data['PRICE'].values

# %%
X = np.column_stack((np.ones(len(X)), X))
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
intercept = theta[0]
slopes = theta[1:]
print("Intercept:", intercept)
print("Slopes:", slopes)
y_pred = X.dot(theta)
# Out:
# Intercept: 147047.7448578996
# Slopes: [  126.49609476 19889.73689333]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X[:, 1], X[:, 2], y, color='blue', label="Data Points")

x1, x2 = np.meshgrid(X[:, 1], X[:, 2])
y_plane = intercept + slopes[0] * x1 + slopes[1] * x2

ax.plot_surface(x1, x2, y_plane, alpha=0.5, color='red', label='Regression Plane')

ax.set_xlabel('Area')
ax.set_ylabel('Bedrooms')
ax.set_zlabel('Price')
ax.set_title('Multiple Variable Linear Regression')

plt.show()

# %%
mean_y = np.mean(y)
ss_tot = np.sum((y - mean_y) ** 2)
ss_res = np.sum((y - y_pred) ** 2)
r_squared = 1 - (ss_res / ss_tot)
print("R-squared Score:", r_squared)
# Out:
# R-squared Score: 0.8712393858950068
