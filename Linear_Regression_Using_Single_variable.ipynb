# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("homeprices.csv")
data
# Out:
#     area   price
# 0   2600  550000
# 1   3000  565000
# 2   3200  610000
# 3   3600  680000
# 4   4000  725000
# ..   ...     ...
# 71  3500  655000
# 72  3700  680000
# 73  4000  735000
# 74  4350  795000
# 75  4500  825000
#
# [76 rows x 2 columns]

# %%
X=data['area'].values
y=data['price'].values

meanx=np.mean(X)
meany=np.mean(y)
print("mean of x=",meanx)
print("mean of y=",meany)
# Out:
# mean of x= 3607.8947368421054
# mean of y= 675697.3684210526

# %%
m=len(X)
num=0
den=0
for i in range(m):
    num+=(X[i]-meanx)*(y[i]-meany)
    den+=(X[i]-meanx)**2
m=num/den
c=meany-(m*meanx)
print("Slope=",m)
print("intercept=",c)
# Out:
# Slope= 142.15730390020383
# intercept= 162808.7798758435

# %%
reg_line=m*X+c
plt.scatter(X,y,color='blue',label="data Points")
plt.plot(X,reg_line,color='red',label='Regression line')
plt.xlabel('area')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
# calculating R2 Score for checking the efficency of models
m=len(X)
num=0
den=0
for i in range(m):
    y_pred=c+m*X[i]
    num+=(y[i]-meany) ** 2
    den+=(y[i]-y_pred) ** 2
    r2=1-num/den
print(r2)
# Out:
# 0.8957358514193773
